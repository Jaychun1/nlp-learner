# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)
print("Project root added:", project_root)
# Out:
# Project root added: /Users/mac/Desktop/nlp-learner

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from src.core.text_classifier import TextClassifier

# %%
texts = [
    "This movie is fantastic and I love it!",
    "I hate this film, it's terrible.",
    "The acting was superb, a truly great experience.",
    "What a waste of time, absolutely boring.",
    "Highly recommend this, a masterpiece.",
    "Could not finish watching, so bad."
]
labels = [1, 0, 1, 0, 1, 0]

# %%
train_texts = texts[:4]
train_labels = labels[:4]
test_texts = texts[4:]
test_labels = labels[4:]

# %%
from src.preprocessing.simple_tokenizer import SimpleTokenizer
from src.representations.count_vectorizer import CountVectorizer
from src.representations.tfidf_vectorizer import TfidfVectorizerCustom

# remove common words like 'the', 'is', etc.
tokenizer = SimpleTokenizer()
count_vectorizer = CountVectorizer(tokenizer=tokenizer)
tfidf_vectorizer = TfidfVectorizerCustom(count_vectorizer)
tfidf_vectorizer.fit(texts)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 9
#       7 count_vectorizer = CountVectorizer(tokenizer=tokenizer)
#       8 tfidf_vectorizer = TfidfVectorizerCustom(count_vectorizer)
# ----> 9 tfidf_vectorizer.fit(texts)
#
# File ~/Desktop/nlp-learner/src/representations/tfidf_vectorizer.py:18, in TfidfVectorizerCustom.fit(self, documents)
#      14 def fit(self, documents):
#      15     """
#      16     Học vocabulary và tính IDF cho từng từ trong corpus.
#      17     """
# ---> 18     super().fit(documents)
#      19     N = len(documents)
#      21     df = [0] * len(self.vocabulary_)
#
# File ~/Desktop/nlp-learner/src/representations/count_vectorizer.py:13, in CountVectorizer.fit(self, corpus)
#      10 unique_tokens = set()
#      12 for doc in corpus:
# ---> 13     tokens = self.tokenizer.tokenize(doc)
#      14     unique_tokens.update(tokens)
# ...

# %%
vectorizer = TfidfVectorizer()
classifier = TextClassifier(vectorizer)
classifier.fit(train_texts, train_labels)

# %%
a = tfidfVectorizer.fit_transform(texts)
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 a = tfidfVectorizer.fit_transform(texts)
#       2 a
#
# File ~/Desktop/nlp-learner/src/representations/tfidf_vectorizer.py:57, in TfidfVectorizerCustom.fit_transform(self, documents)
#      53 def fit_transform(self, documents):
#      54     """
#      55     Fit và transform đồng thời.
#      56     """
# ---> 57     self.fit(documents)
#      58     return self.transform(documents)
#
# File ~/Desktop/nlp-learner/src/representations/tfidf_vectorizer.py:18, in TfidfVectorizerCustom.fit(self, documents)
#      14 def fit(self, documents):
#      15     """
#      16     Học vocabulary và tính IDF cho từng từ trong corpus.
#      17     """
# ---> 18     super().fit(documents)
#      19     N = len(documents)
#      21     df = [0] * len(self.vocabulary_)
#
# ...

# %%
tfidfMatrix = tfidfVectorizer.fit_transform(texts)
print("TF-IDF matrix:\n", tfidfMatrix)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 tfidfMatrix = tfidfVectorizer.fit_transform(texts)
#       2 print("TF-IDF matrix:\n", tfidfMatrix)
#
# File ~/Desktop/nlp-learner/src/representations/tfidf_vectorizer.py:57, in TfidfVectorizerCustom.fit_transform(self, documents)
#      53 def fit_transform(self, documents):
#      54     """
#      55     Fit và transform đồng thời.
#      56     """
# ---> 57     self.fit(documents)
#      58     return self.transform(documents)
#
# File ~/Desktop/nlp-learner/src/representations/tfidf_vectorizer.py:18, in TfidfVectorizerCustom.fit(self, documents)
#      14 def fit(self, documents):
#      15     """
#      16     Học vocabulary và tính IDF cho từng từ trong corpus.
#      17     """
# ---> 18     super().fit(documents)
#      19     N = len(documents)
# ...

# %%
# Display results
print("Feature names:", tfidfVectorizer.get_feature_names_out())
print("TF-IDF matrix shape:", tfidfVectorizer.shape)

# Optionally convert to array or DataFrame for inspection
import pandas as pd
df = pd.DataFrame(tfidfVectorizer.toarray(), columns=vectorizer.get_feature_names_out())
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Display results
# ----> 2 print("Feature names:", tfidfVectorizer.get_feature_names_out())
#       3 print("TF-IDF matrix shape:", tfidfVectorizer.shape)
#       5 # Optionally convert to array or DataFrame for inspection
#
# AttributeError: 'TfidfVectorizerCustom' object has no attribute 'get_feature_names_out'
